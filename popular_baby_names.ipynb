# %%
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\Smako\\anaconda3\\envs\\PythonData\\Lib\\site-packages\\psycopg2\\_psycopg.cp36-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#   Using cached psycopg2_binary-2.8.6-cp36-cp36m-win_amd64.whl (1.1 MB)
# Installing collected packages: psycopg2-binary

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
alaska_names_file = "Resources/AlaskaNames.csv"
alaska_names_df = pd.read_csv(alaska_names_file)
alaska_names_df.sample(15)
# Out:
#               Id       Name  Year Gender State  Count
# 926250    926251     Marcus  2017      M    AK      6
# 233450    233451      Nancy  1954      F    AK     44
# 654634    654635        Bob  1960      M    AK      8
# 922574    922575  Christian  2002      M    AK     30
# 890341    890342      Shaun  1985      M    AK      9
# 105692    105693    Patrick  1969      M    AK     31
# 1063475  1063476       Carl  1982      M    AK     13
# 963310    963311   Jeanette  1985      F    AK      5
# 911641    911642      Naomi  2015      F    AK     13
# 1029090  1029091      Tommy  1937      M    AK      6
# 447290    447291      Chloe  2011      F    AK     39
# 1156930  1156931     Jeremy  2013      M    AK      6
# 907276    907277     Brandy  1994      F    AK     10
# 1296017  1296018    Preston  1986      M    AK      7
# 610471    610472       Anna  1957      F    AK     24

# %%
national_names_files = "Resources/NationalNames.csv"
national_names_df = pd.read_csv(national_names_files)
national_names_df.head()
# Out:
#    Id       Name  Year Gender  Count
# 0   1       Mary  1880      F   7065
# 1   2       Anna  1880      F   2604
# 2   3       Emma  1880      F   2003
# 3   4  Elizabeth  1880      F   1939
# 4   5     Minnie  1880      F   1746

# %% [markdown]
# ### Transform Alaska Names DataFrame

# %%
# Create a filtered dataframe from specific columns
alaska_columns = ["Name", "Year", "Gender", "Count"]
alaska_transformed = alaska_names_df[alaska_columns].copy()

# Clean the data by dropping duplicates and setting the index
alaska_transformed.drop_duplicates("Name", inplace=True)
alaska_transformed.set_index("Name", inplace=True)

alaska_transformed.sample(10)
# Out:
#           Year Gender  Count
# Name
# Scarlett  2006      F      5
# Leon      1967      M      5
# Amari     2018      M      5
# Lexi      2010      F      7
# Janis     1952      F      5
# Nora      1936      F      6
# Kane      2014      M      5
# Taryn     1993      F      6
# Aaron     1956      M      6
# Mckenna   1996      F      6

# %% [markdown]
# ### Transform National Names

# %%
# Create a filtered dataframe from specific columns
national_columns = ["Name", "Year", "Gender", "Count"]
national_transformed = national_names_df[national_columns].copy()

# Clean the data by dropping duplicates and setting the index
national_transformed.drop_duplicates("Name", inplace=True)
national_transformed.set_index("Name", inplace=True)

national_transformed.sample(10)
# Out:
#          Year Gender  Count
# Name
# Kaidin   2000      M     12
# Yasar    2018      M      5
# Athlene  1918      F      5
# Minelva  1970      F      5
# Kalauni  2016      F      5
# Ysidoro  1921      M      5
# Abbey    1914      M      5
# Mati     2001      F      6
# Gi       1988      F      5
# Alli     1916      F      5

# %% [markdown]
# ### Create Database Connection

# %%
connection_string = "postgres:pgadmin@localhost:5432/babynames_db"
engine = create_engine(f'postgresql://{connection_string}')

# %% [markdown]
# ### Confirm Engine

# %%
 # Confirm tables
engine.table_names()
# Out:
# ['alaska_names', 'national_names']

# %% [markdown]
# ### Load DataFrames into database

# %%
 alaska_transformed.to_sql(name='alaska_names', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Name" of relation "alaska_names" does not exist
# LINE 1: INSERT INTO alaska_names ("Name", "Year", "Gender", "Count")...
#                                   ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-15-263a93f57468> in <module>
# ----> 1 alaska_transformed.to_sql(name='alaska_names', con=engine, if_exists='append', index=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1018             )
#    1019         else:
# -> 1020             return meth(self, multiparams, params)
#    1021
#    1022     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1137             distilled_params,
#    1138             compiled_sql,
# -> 1139             distilled_params,
#    1140         )
#    1141         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1322         except BaseException as e:
#    1323             self._handle_dbapi_exception(
# -> 1324                 e, statement, parameters, cursor, context
#    1325             )
#    1326
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1516             elif should_wrap:
#    1517                 util.raise_(
# -> 1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#    1520             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1262                 if not evt_handled:
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#    1266             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "Name" of relation "alaska_names" does not exist
# LINE 1: INSERT INTO alaska_names ("Name", "Year", "Gender", "Count")...
#                                   ^
#
# [SQL: INSERT INTO alaska_names ("Name", "Year", "Gender", "Count") VALUES (%(Name)s, %(Year)s, %(Gender)s, %(Count)s)]
# [parameters: ({'Name': 'Mary', 'Year': 1910, 'Gender': 'F', 'Count': 14}, {'Name': 'Annie', 'Year': 1910, 'Gender': 'F', 'Count': 12}, {'Name': 'Anna', 'Year': 1910, 'Gender': 'F', 'Count': 10}, {'Name': 'Margaret', 'Year': 1910, 'Gender': 'F', 'Count': 8}, {'Name': 'Helen', 'Year': 1910, 'Gender': 'F', 'Count': 7}, {'Name': 'Elsie', 'Year': 1910, 'Gender': 'F', 'Count': 6}, {'Name': 'Lucy', 'Year': 1910, 'Gender': 'F', 'Count': 6}, {'Name': 'Dorothy', 'Year': 1910, 'Gender': 'F', 'Count': 5}  ... displaying 10 of 1642 total bound parameter sets ...  {'Name': 'Ellis', 'Year': 2019, 'Gender': 'M', 'Count': 5}, {'Name': 'Leonidas', 'Year': 2019, 'Gender': 'M', 'Count': 5})]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
national_transformed.to_sql(name='national_names', con=engine, if_exists='append', index=True)
