# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
alaska_names_file = "Resources/AlaskaNames.csv"
alaska_names_df = pd.read_csv(alaska_names_file)
alaska_names_df.sample(15)
# Out:
#               Id     Name  Year Gender State  Count
# 1234082  1234083      Dan  1961      M    AK      5
# 784155    784156     Joan  1956      F    AK      7
# 705900    705901    Elena  2001      F    AK     10
# 465856    465857    Diana  1958      F    AK     18
# 924182    924183  Timothy  2009      M    AK     10
# 411636    411637    Tracy  1979      F    AK     11
# 472083    472084    Helen  1990      F    AK      5
# 226108    226109   Colton  1995      M    AK     19
# 666358    666359    Betty  1923      F    AK      6
# 915243    915244   Norman  1960      M    AK     16
# 635099    635100  Atticus  2011      M    AK      6
# 1038194  1038195  Matthew  2001      M    AK     47
# 1270589  1270590   Xander  2004      M    AK     13
# 267902    267903  Breanna  1984      F    AK      8
# 998652    998653   Vivian  2015      F    AK      6

# %%
national_names_files = "Resources/NationalNames.csv"
national_names_df = pd.read_csv(national_names_files)
national_names_df.head()
# Out:
#    Id       Name  Year Gender  Count
# 0   1       Mary  1880      F   7065
# 1   2       Anna  1880      F   2604
# 2   3       Emma  1880      F   2003
# 3   4  Elizabeth  1880      F   1939
# 4   5     Minnie  1880      F   1746

# %% [markdown]
# ### Transform Alaska Names DataFrame

# %%
# Create a filtered dataframe from specific columns
alaska_columns = ["baby_name", "birth_year", "gender", "total"]
alaska_names_df.columns = alaska_names_

# Clean the data by dropping duplicates and setting the index
alaska_transformed.drop_duplicates("baby_name", inplace=True)
#alaska_transformed.set_index("Name", inplace=True)

alaska_transformed.sample(10)

# Create a filtered dataframe from specific columns
national_columns = ["id", "baby_name", "birth_year", "gender", "total"]
national_names_df.columns=national_columns
#national_transformed=national_transformed[["baby_name", "birth_year", "gender", "total"]]

# Clean the data by dropping duplicates and setting the index
national_transformed.drop_duplicates("baby_name", inplace=True)
national_transformed=national_transformed[["baby_name", "birth_year", "gender", "total"]]
#national_transformed.set_index("Name", inplace=True)

national_transformed.sample(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-15968094b05c> in <module>
#       1 # Create a filtered dataframe from specific columns
#       2 alaska_columns = ["baby_name", "birth_year", "gender", "total"]
# ----> 3 alaska_transformed = alaska_names_df[alaska_columns].copy()
#       4
#       5 # Clean the data by dropping duplicates and setting the index
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
# ...

# %% [markdown]
# ### Transform National Names

# %%
# Create a filtered dataframe from specific columns
national_columns = ["id", "baby_name", "birth_year", "gender", "total"]
national_names_df.columns=national_columns
#national_transformed=national_transformed[["baby_name", "birth_year", "gender", "total"]]

# Clean the data by dropping duplicates and setting the index
national_transformed.drop_duplicates("baby_name", inplace=True)
national_transformed=national_transformed[["baby_name", "birth_year", "gender", "total"]]
#national_transformed.set_index("Name", inplace=True)

national_transformed.sample(10)
# Out:
# /Users/naldrich/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#          baby_name  birth_year gender  total
# 1910825    Thylane        2017      F      5
# 681192      Jerred        1968      M      9
# 1376227      Aelyn        2001      F      6
# 892993      Jylian        1981      F      6
# 110125       Kline        1913      M     12
# 615988      Likita        1963      F      5
# 129072      Yewell        1915      M      5
# 492972   Devereaux        1952      M      5
# 874393    Antonica        1980      F      5
# 972606     Eliscia        1985      F      5

# %% [markdown]
# ### Create Database Connection

# %%
connection_string = "postgres:pgadmin@localhost:5432/babynames_db"
engine = create_engine(f'postgresql://{connection_string}')

# %% [markdown]
# ### Confirm Engine

# %%
 # Confirm tables
engine.table_names()
# Out:
# /Users/naldrich/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
# ['alaska_names', 'national_names']

# %% [markdown]
# ### Load DataFrames into database

# %%
 alaska_transformed.to_sql(name='alaska_names', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1685                     self.dialect.do_executemany(
# -> 1686                         cursor, statement, parameters, context
#    1687                     )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     900                 fetch=bool(context.compiled.returning),
# --> 901                 **kwargs
#     902             )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1291         parts[-1:] = post
# ...

# %%
national_transformed.to_sql(name='national_names', con=engine, if_exists='append', index=False)
